# %%
import PIL
import pytesseract
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'D://Tesseract//tesseract.exe'

# %%
image_path = "train/invoice/2_jpg.rf.4b78fbc11b45b8b0db60c3cf47d2c37e.jpg"
image = PIL.Image.open(image_path)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1132x1600>

# %%
from googletrans import Translator
translator = Translator()
text = pytesseract.image_to_string(image)
translated_text = translator.translate(text, dest='en').text
print(translated_text)
print(text)
# Out:
# ——————“‘‘ te
#
# Neo Yiserercsho
#
# ysuse pele sz2Easirse8 (AE) $2e 894 Eed
# Jo: WCCOUE UO : Pyove poawet wervos
# Fight 200°0
# WX 200°0
# 2nbiolvl 200°0
# Xonk Ceclibflov Pele e@5000 25000
# Konk Qeectibflov Gels 50:00 25000
# ronk qeectibflov peels 250'00 25000
# “DeecBiblion PBICE
# Conuela
# Gaiva iws
# yatee pele
# Aon yiwwse pele
# PSSFE YS SOS!
# Yo ts
#
# Aonb COWBDWNA UVWE HEBE
#
# Imaoice
# —————“‘ te
#
# Neo yiserercsho
#
# ysuse Pele sz2easirse8 (ae) $2e 894 eed
# jo: WCCONUE uo : pyove poAwert Wervos
# LOLve 200°00
# wx 200°00
# 2nBiolvl 200°00
# Xonk qeeclibflov pele e@5000 25000
# Konk qeectibflov GELS 50:00 25000
# Ronk qeectibflov pels 250'00 25000
# “DEeCBIbLION pBICE LOL
# COnUELA
# gaaiva IWS
# yaateee PELE
# Aon yIWwse pele
# pssfe yS SOS!
# yo ts
#
# AONB COWbDWNA UVWE HEBE
#
# IMAOICE
